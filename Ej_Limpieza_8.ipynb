# %% [markdown]
# # PRACTICA 1 - LIMPIEZA DE DATOS
#
# **Equipo:** 8
#
# **Grupo:** 002 (Miercoles 7-10 pm)
#
# **Integrantes:**
#
# * 1872932 Huerta Torres Daniela Paola
#
# * 1855188 Aguilar Ortiz Verónica Vanessa
#
# * 1751125 Rodríguez Chaires Fernando Jahir
#
# * 1857876 Jalomo Hernández Miguel Ángel

# %% [markdown]
# ## BASE DE DATOS : Netflix Movies and TV Shows
#
# **URL:** https://www.kaggle.com/shivamb/netflix-shows?select=netflix_titles.csv

# %%
import pandas as pd
import numpy as np
import json

df=pd.read_csv("C:/Users/Daniela/Desktop/Daniela/Facultad/7mo sem/Mineria/googleplaystore.csv",encoding='utf-8')
print("Los datos sin manipulación son:")
df
# Out:
# Los datos sin manipulación son:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape #numero de columnas y filas
# Out:
# (10841, 13)

# %%
df.head(11) #primeras 10 datos de la tabla
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
#
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#cambiamos el nombre de nuestras columnas
df.rename(columns={'Category':'Categoria','Reviews':'Criticas','Size':'Tamaño',
                    'Installs':'Instalaciones','Type':'Tipo','Price':'Precio',
                   'Content Rating':'Clasificación','Genres':'Generos','Last Updated':'Ultima Actialización',
                    'Current Ver':'Versión Actual','Android Ver':'Versión de Android'})
# Out:
#                                                      App            Categoria  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Tipos de datos de nuestras columnas
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
df.Rating.astype("float") 
#No se puede convertir un flotante a un intero, ni un caracter a flotante
# Out:
# 0        4.1
# 1        3.9
# 2        4.7
# 3        4.5
# 4        4.3
#         ...
# 10836    4.5
# 10837    5.0
# 10838    NaN
# 10839    4.5
# 10840    4.5
# Name: Rating, Length: 10841, dtype: float64

# %%
df.describe() # informacion resumida de nuestra base de datos
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.isnull().sum() #Comrpbando datos faltantes
#Ayuda https://miamioh.instructure.com/courses/38817/pages/data-cleaning
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
# porcentaje del datos perdidos....
(df.isnull().sum()/df.shape[0])*100
#Ayuda https://www.kaggle.com/adityajohnny/google-app-play-store
# Out:
# App                0.000000
# Category           0.000000
# Rating            13.596532
# Reviews            0.000000
# Size               0.000000
# Installs           0.000000
# Type               0.009224
# Price              0.000000
# Content Rating     0.009224
# Genres             0.000000
# Last Updated       0.000000
# Current Ver        0.073794
# Android Ver        0.027673
# dtype: float64

# %%
df.Category.unique() #vemos los tipos de categorias que contiene la columna categoria
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
AAD = df[df['Category']=='ART_AND_DESING']

AAD.to_csv('Solo_AAD.csv', index=False) #agrupamos un tipo de categoria

# %%
AAD_vs_Installs = df.loc[df.Category == 'ART_AND_DESING'].Installs

# %% [markdown]
# A continuación se designaron algunas columnas para ser removidas, ya que tenemos en mente realizar un estudio acerca de que generos son los que tienen mas instalaciones, y ver si que el precio de la app aumente y que ciertas aplicaciones no son para todos afecte en la cantidad de instalaciones.

# %%
cf=df.drop(['Size','Last Updated','Current Ver','Android Ver','Reviews'],axis = 1 )
#eliminamos ciertas columnas que creemos inecesarias

# %%
cf
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# * **Preguntas Interesantes**

# %% [markdown]
# **¿Para que me puede servir estas agrupaciones para la práctica siguiente?**
#
# Por que puede haber ocasiones que nuestro enfoque va hacia un tipo de clase, esta funcion nos da la facilidad de filtrar
# o tomar una muestra de todo el conjunto de datos que en este caso seria la clase que estariamos tomando
#
# **Importancia del analisis previo de los datos antes de iniciar las modificaciones.**
#
# En ciertos momentos nos podemos encontrar con gan cantidad de casillas vacias en ciertas columnas, y teniendo esto en cuenta, es informacion que tenemos que desechar o eliminar por que esta incompleta, y eso hara que quizas nuestra infomacion no sea completamente exacta al final al obtener resultados, y en dado caso el resultado puede variar mucho por esa informacion que tuvo que ser retirada.
